# %%
import numpy as np
import pandas as pd
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
# Convert categorical data to numeric and separate target feature for training data
train_df
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0           57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1          141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2          321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3           11778   11778     3000.0    0.1240       100.22           RENT
# 4          169382  169382    30000.0    0.1612      1056.49       MORTGAGE
# ...           ...     ...        ...       ...          ...            ...
# 12175      354912  354912    19975.0    0.2565       801.09           RENT
# 12176      354944  354944    15000.0    0.1774       540.34           RENT
# 12177      354973  354973     3600.0    0.1862       131.28           RENT
# 12178      355002  355002    15000.0    0.0881       475.68       MORTGAGE
# 12179      355307  355307    15000.0    0.1774       540.34           RENT
#
#        annual_inc verification_status loan_status pymnt_plan  ...  \
# ...

# %%
test_df
# Out:
#       Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0          67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1          25429  25429     6000.0    0.1524       208.70           RENT
# 2          38496  38496     3600.0    0.1695       128.27           RENT
# 3          19667  19667    20000.0    0.1524       478.33           RENT
# 4          37505  37505     3600.0    0.1240       120.27           RENT
# ...          ...    ...        ...       ...          ...            ...
# 4697       77282  77282    30000.0    0.1240       673.42           RENT
# 4698       77291  77291    24000.0    0.0756       747.22           RENT
# 4699       77292  77292    10000.0    0.2305       387.36           RENT
# 4700       77297  77297     8000.0    0.1862       205.86           RENT
# 4701       77304  77304    30000.0    0.2055      1123.34           RENT
#
#       annual_inc verification_status loan_status pymnt_plan  ...  \
# ...

# %%
del train_df['Unnamed: 0']

# %%
del train_df['index']

# %%
del test_df['Unnamed: 0']

# %%
del test_df['index']

# %%
# Convert categorical data to numeric and separate target feature for testing data
train_df = pd.get_dummies(train_df, columns=['home_ownership','verification_status',
                                             'application_type','hardship_flag',
                                             'debt_settlement_flag','initial_list_status',
                                             'pymnt_plan','loan_status'])
train_df
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0        13375.0    0.1797       483.34    223000.0  29.99          0.0
# 1        21000.0    0.1308       478.68    123000.0  11.26          2.0
# 2        20000.0    0.1240       448.95    197000.0  11.28          0.0
# 3         3000.0    0.1240       100.22     45000.0  18.08          0.0
# 4        30000.0    0.1612      1056.49    133000.0  27.77          0.0
# ...          ...       ...          ...         ...    ...          ...
# 12175    19975.0    0.2565       801.09     28000.0  28.42          0.0
# 12176    15000.0    0.1774       540.34     50000.0  23.43          4.0
# 12177     3600.0    0.1862       131.28     60000.0  28.80          0.0
# 12178    15000.0    0.0881       475.68     62000.0  11.44          0.0
# 12179    15000.0    0.1774       540.34     54080.0  21.66          1.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# ...

# %%
del train_df['loan_status_low_risk']
train_df=train_df.rename(columns={'loan_status_high_risk':'loan_status'})

# %%
# Convert categorical data to numeric and separate target feature for Training data
test_df = pd.get_dummies(test_df, columns=['home_ownership','verification_status',
                                           'application_type','hardship_flag',
                                           'debt_settlement_flag','initial_list_status',
                                           'pymnt_plan','loan_status'])
test_df
# Out:
#       loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0       40000.0    0.0819       814.70    140000.0  19.75          0.0
# 1        6000.0    0.1524       208.70     55000.0  11.52          2.0
# 2        3600.0    0.1695       128.27     42000.0   6.74          0.0
# 3       20000.0    0.1524       478.33    100000.0  12.13          0.0
# 4        3600.0    0.1240       120.27     50000.0  16.08          0.0
# ...         ...       ...          ...         ...    ...          ...
# 4697    30000.0    0.1240       673.42    140480.0  15.74          0.0
# 4698    24000.0    0.0756       747.22     50000.0  26.81          0.0
# 4699    10000.0    0.2305       387.36     33000.0  38.51          0.0
# 4700     8000.0    0.1862       205.86     38000.0  16.36          0.0
# 4701    30000.0    0.2055      1123.34    180000.0  12.06          0.0
#
#       inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0                1.0      18.0      0.0     9471.0  ...
# ...

# %%
del test_df['loan_status_low_risk']
test_df =test_df.rename(columns={'loan_status_high_risk':'loan_status'})

# %%
# add missing dummy variables to testing set
test_df['debt_settlement_flag_Y'] = 0
X_train = train_df.drop('loan_status', axis=1)
y_train = train_df['loan_status']

# %%
y_test = test_df['loan_status']
X_test = test_df.drop('loan_status', axis=1)

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
Log_Reg_classifier = LogisticRegression()
Log_Reg_classifier.fit(X_train, y_train)
# Out:
# C:\Users\jagde\anaconda33\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Train a Random Forest Classifier model and print the model score
Ran_For_Class = (RandomForestClassifier(random_state=1, n_estimators=3).fit(X_train, y_train))

# %%
# Print Testing scores for both logisitic regression classifier and random forest classifier
print(f" Score from testing data using Logisitic Regression: {Log_Reg_classifier.score(X_test, y_test)}")
print(f'Score from testing data using Random forest classifier: {Ran_For_Class.score(X_test, y_test)}')
# Out:
#  Score from testing data using Logisitic Regression: 0.5168013611229264
# Score from testing data using Random forest classifier: 0.5857082092726499

# %%
# Scale the data
scaler = StandardScaler().fit(X_train)
scaled_X_train = scaler.transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
scaled_Log_Reg_classifier = LogisticRegression().fit(scaled_X_train, y_train)

print(f'Score from scaled testing data using logistic Regression: {scaled_Log_Reg_classifier.score(scaled_X_test, y_test)}')
# Out:
# Score from scaled testing data using logistic Regression: 0.7501063377286261
# C:\Users\jagde\anaconda33\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
scaled_Ran_For_Class = RandomForestClassifier(random_state=1, n_estimators=3).fit(scaled_X_train, y_train)
print(f'Score from scaled testing data using random forest classifier: {scaled_Ran_For_Class.score(scaled_X_test, y_test)}')
# Out:
# Score from scaled testing data using random forest classifier: 0.5850701829008932

# %%
#Score from scaled testing data using logistic Regression: 0.7501063377286261
#Score from scaled testing data using random forest classifier: 0.5850701829008932
# 0.7501063377286261 > 0.5850701829008932
#Logistic regression model yielded a higher score of 0.75 compared to the random forest score of 0.59.
